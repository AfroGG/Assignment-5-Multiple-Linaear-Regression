# %% [markdown]
#  # Multi Linear Regression

# %% [markdown]
# # Assignment-5, Toyota Corolla

# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.graphics.regressionplots import influence_plot

# %%
#Import dataset
df =pd.read_csv('ToyotaCorolla.csv',encoding='latin1')
df
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# ...

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Model             1436 non-null   object
#  2   Price             1436 non-null   int64
#  3   Age_08_04         1436 non-null   int64
#  4   Mfg_Month         1436 non-null   int64
#  5   Mfg_Year          1436 non-null   int64
#  6   KM                1436 non-null   int64
#  7   Fuel_Type         1436 non-null   object
#  8   HP                1436 non-null   int64
#  9   Met_Color         1436 non-null   int64
#  10  Color             1436 non-null   object
#  11  Automatic         1436 non-null   int64
#  12  cc                1436 non-null   int64
#  13  Doors             1436 non-null   int64
#  14  Cylinders         1436 non-null   int64
#  15  Gears             1436 non-null   int64
# ...

# %%
df2=pd.concat([df.iloc[:,2:4],df.iloc[:,6:7],df.iloc[:,8:9],df.iloc[:,12:14],df.iloc[:,15:18]],axis=1)
df2
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
df3=df2.rename({'Age_08_04':'Age','cc':'CC','Quarterly_Tax':'QT'},axis=1)
df3
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1431   7500   69  20544   86  1300      3      5   69    1025
# 1432  10845   72  19000   86  1300      3      5   69    1015
# 1433   8500   71  17016   86  1300      3      5   69    1015
# 1434   7250   70  16916   86  1300      3      5   69    1015
# 1435   6950   76      1  110  1600      5      5   19    1114
#
# [1436 rows x 9 columns]

# %%
df3[df3.duplicated()]
# Out:
#      Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 113  24950    8  13253  116  2000      5      5  234    1320

# %%
df4=df3.drop_duplicates().reset_index(drop=True)
df4
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1430   7500   69  20544   86  1300      3      5   69    1025
# 1431  10845   72  19000   86  1300      3      5   69    1015
# 1432   8500   71  17016   86  1300      3      5   69    1015
# 1433   7250   70  16916   86  1300      3      5   69    1015
# 1434   6950   76      1  110  1600      5      5   19    1114
#
# [1435 rows x 9 columns]

# %%
df4.describe()
# Out:
#               Price          Age             KM           HP            CC  \
# count   1435.000000  1435.000000    1435.000000  1435.000000   1435.000000
# mean   10720.915679    55.980488   68571.782578   101.491986   1576.560976
# std     3608.732978    18.563312   37491.094553    14.981408    424.387533
# min     4350.000000     1.000000       1.000000    69.000000   1300.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.000000
# 50%     9900.000000    61.000000   63451.000000   110.000000   1600.000000
# 75%    11950.000000    70.000000   87041.500000   110.000000   1600.000000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.000000
#
#              Doors        Gears           QT       Weight
# count  1435.000000  1435.000000  1435.000000  1435.000000
# mean      4.032753     5.026481    87.020209  1072.287108
# std       0.952667     0.188575    40.959588    52.251882
# min       2.000000     3.000000    19.000000  1000.000000
# ...

# %% [markdown]
# # Data Visualization

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.distplot(df4["Price"])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.distplot(df4["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df4["KM"])
# Out:
# <AxesSubplot:xlabel='KM', ylabel='Density'>

# %%
sns.distplot(df4["HP"])
# Out:
# <AxesSubplot:xlabel='HP', ylabel='Density'>

# %%
sns.distplot(df4["CC"])
# Out:
# <AxesSubplot:xlabel='CC', ylabel='Density'>

# %%
sns.distplot(df4["Doors"])
# Out:
# <AxesSubplot:xlabel='Doors', ylabel='Density'>

# %%
sns.distplot(df4["Gears"])
# Out:
# <AxesSubplot:xlabel='Gears', ylabel='Density'>

# %%
sns.distplot(df4["QT"])
# Out:
# <AxesSubplot:xlabel='QT', ylabel='Density'>

# %%
sns.distplot(df4["Weight"])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %% [markdown]
# # Data Transformation

# %% [markdown]
# 1. Log Transformation: Transform the response variable from y to log(y).

# %%
#create log-transformed data
df_log = np.log(df4)

# %%
#define grid of plots
fig, axs = plt.subplots(nrows=1, ncols=2)

#create histograms
axs[0].hist(df4)
axs[1].hist(df_log)

#add title to each histogram
axs[0].set_title('Original Data')
axs[1].set_title('Log transformed data')
# Out:
# Text(0.5, 1.0, 'Log transformed data')

# %% [markdown]
# 2. Square Root Transformation: Transform the response variable from y to √y.

# %%
#create log-transformed data
df_log = np.sqrt(df4)

# %%
#define grid of plots
fig, axs = plt.subplots(nrows=1, ncols=2)

#create histograms
axs[0].hist(df4)
axs[1].hist(df_log)

#add title to each histogram
axs[0].set_title('Original Data')
axs[1].set_title('Square Root Transformed Data')
# Out:
# Text(0.5, 1.0, 'Square Root Transformed Data')

# %% [markdown]
# Cube Root Transformation: Transform the response variable from y to y1/3.

# %%
#create log-transformed data
df_log = np.cbrt(df4)

# %%
#define grid of plots
fig, axs = plt.subplots(nrows=1, ncols=2)

#create histograms
axs[0].hist(df4)
axs[1].hist(df_log)

#add title to each histogram
axs[0].set_title('Original Data')
axs[1].set_title('Cube Root Transformed Data')
# Out:
# Text(0.5, 1.0, 'Cube Root Transformed Data')

# %% [markdown]
# 4. Box Cox transformation in Python

# %%
from scipy.stats import boxcox

# Box-Cox Transformation in Python
df4.insert(len(df4.columns), 'B_Boxcox', 
              boxcox(df4.iloc[:, 0])[0])

# %%
#define grid of plots
fig, axs = plt.subplots(nrows=1, ncols=2)

#create histograms
axs[0].hist(df4)
axs[1].hist(df_log)

#add title to each histogram
axs[0].set_title('Original Data')
axs[1].set_title('Boxcox data')
# Out:
# Text(0.5, 1.0, 'Boxcox data')

# %% [markdown]
# # Correlation Analysis

# %%
df.corr()
# Out:
#                         Id     Price  Age_08_04  Mfg_Month  Mfg_Year  \
# Id                1.000000 -0.738250   0.906132   0.043742 -0.919523
# Price            -0.738250  1.000000  -0.876590  -0.018138  0.885159
# Age_08_04         0.906132 -0.876590   1.000000  -0.123255 -0.983661
# Mfg_Month         0.043742 -0.018138  -0.123255   1.000000 -0.057416
# Mfg_Year         -0.919523  0.885159  -0.983661  -0.057416  1.000000
# KM                0.273298 -0.569960   0.505672  -0.020630 -0.504974
# HP               -0.109375  0.314990  -0.156622  -0.039312  0.164697
# Met_Color        -0.079713  0.108905  -0.108150   0.030266  0.103310
# Automatic         0.066265  0.033081   0.031717   0.009146 -0.033567
# cc               -0.117704  0.126389  -0.098084   0.037387  0.091892
# Doors            -0.130207  0.185326  -0.148359  -0.012069  0.151442
# Cylinders              NaN       NaN        NaN        NaN       NaN
# Gears            -0.043343  0.063104  -0.005364  -0.013063  0.007766
# ...

# %%
sns.set_style(style='darkgrid')
sns.pairplot(df4)

# %% [markdown]
# # Model Building

# %%
model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=df4).fit()

# %% [markdown]
# # Model Testing

# %%
# Finding Coefficient parameters
model.params
# Out:
# Intercept   -5472.540368
# Age          -121.713891
# KM             -0.020737
# HP             31.584612
# CC             -0.118558
# Doors          -0.920189
# Gears         597.715894
# QT              3.858805
# Weight         16.855470
# dtype: float64

# %%
# Finding tvalues and pvalues
model.tvalues , np.round(model.pvalues,5)
# Out:
# (Intercept    -3.875273
#  Age         -46.551876
#  KM          -16.552424
#  HP           11.209719
#  CC           -1.316436
#  Doors        -0.023012
#  Gears         3.034563
#  QT            2.944198
#  Weight       15.760663
#  dtype: float64,
#  Intercept    0.00011
#  Age          0.00000
#  KM           0.00000
#  HP           0.00000
#  CC           0.18824
#  Doors        0.98164
#  Gears        0.00245
#  QT           0.00329
#  Weight       0.00000
#  dtype: float64)

# %%
# Finding rsquared values
model.rsquared , model.rsquared_adj   # Model accuracy is 86.17%
# Out:
# (0.8625200256947, 0.8617487495415146)

# %%
# Build SLR and MLR models for insignificant variables 'CC' and 'Doors'
# Also find their tvalues and pvalues
slr_c=smf.ols('Price~CC',data=df4).fit()
slr_c.tvalues , slr_c.pvalues # CC has significant pvalue
# Out:
# (Intercept    24.879592
#  CC            4.745039
#  dtype: float64,
#  Intercept    7.236022e-114
#  CC            2.292856e-06
#  dtype: float64)

# %%
slr_d=smf.ols('Price~Doors',data=df4).fit()
slr_d.tvalues , slr_d.pvalues # Doors has significant pvalue
# Out:
# (Intercept    19.421546
#  Doors         7.070520
#  dtype: float64,
#  Intercept    8.976407e-75
#  Doors        2.404166e-12
#  dtype: float64)

# %%
mlr_cd=smf.ols('Price~CC+Doors',data=df4).fit()
mlr_cd.tvalues , mlr_cd.pvalues # CC & Doors have significant pvalue
# Out:
# (Intercept    12.786341
#  CC            4.268006
#  Doors         6.752236
#  dtype: float64,
#  Intercept    1.580945e-35
#  CC           2.101878e-05
#  Doors        2.109558e-11
#  dtype: float64)

# %% [markdown]
# # Model Validation Techniques

# %% [markdown]
# Two Techniques: 1. Collinearity check And 2. Residual Analysis

# %%
# Collinearity Problem Check
# Calculate VIF = 1/(1-Rsquare) for all independent variables

rsq_age=smf.ols('Age~KM+HP+CC+Doors+Gears+QT+Weight',data=df4).fit().rsquared
vif_age=1/(1-rsq_age)

rsq_KM=smf.ols('KM~Age+HP+CC+Doors+Gears+QT+Weight',data=df4).fit().rsquared
vif_KM=1/(1-rsq_KM)

rsq_HP=smf.ols('HP~Age+KM+CC+Doors+Gears+QT+Weight',data=df4).fit().rsquared
vif_HP=1/(1-rsq_HP)

rsq_CC=smf.ols('CC~Age+KM+HP+Doors+Gears+QT+Weight',data=df4).fit().rsquared
vif_CC=1/(1-rsq_CC)

rsq_DR=smf.ols('Doors~Age+KM+HP+CC+Gears+QT+Weight',data=df4).fit().rsquared
vif_DR=1/(1-rsq_DR)

rsq_GR=smf.ols('Gears~Age+KM+HP+CC+Doors+QT+Weight',data=df4).fit().rsquared
vif_GR=1/(1-rsq_GR)

rsq_QT=smf.ols('QT~Age+KM+HP+CC+Doors+Gears+Weight',data=df4).fit().rsquared
vif_QT=1/(1-rsq_QT)

rsq_WT=smf.ols('Weight~Age+KM+HP+CC+Doors+Gears+QT',data=df4).fit().rsquared
vif_WT=1/(1-rsq_WT)

# Putting the values in Dataframe format
d1={'Variables':['Age','KM','HP','CC','Doors','Gears','QT','Weight'],
    'Vif':[vif_age,vif_KM,vif_HP,vif_CC,vif_DR,vif_GR,vif_QT,vif_WT]}
Vif_df=pd.DataFrame(d1)
Vif_df
# Out:
#   Variables       Vif
# 0       Age  1.876236
# 1        KM  1.757178
# 2        HP  1.419180
# 3        CC  1.163470
# 4     Doors  1.155890
# 5     Gears  1.098843
# 6        QT  2.295375
# 7    Weight  2.487180

# %% [markdown]
# None variable has VIF>20, No Collinearity, so consider all varaibles in Regression equation

# %%
# Residual Analysis
# Test for Normality of Residuals (Q-Q Plot) using residual model (model.resid)
sm.qqplot(model.resid,line='q') # 'q' - A line is fit through the quartiles # line = '45'- to draw the 45-degree diagonal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid>6000))  # outliar detection from above QQ plot of residuals
# Out:
# [array([109, 146, 522], dtype=int64)]

# %%
list(np.where(model.resid<-6000))
# Out:
# [array([220, 600, 959], dtype=int64)]

# %%
# Test for Homoscedasticity or Heteroscedasticity (plotting model's standardized fitted values vs standardized residual values)

def standard_values(vals) : return (vals-vals.mean())/vals.std()  # User defined z = (x - mu)/sigma

# %%
plt.scatter(standard_values(model.fittedvalues),standard_values(model.resid))
plt.title('Residual Plot')
plt.xlabel('standardized fitted values')
plt.ylabel('standardized residual values')
plt.show()

# %%
# Test for errors or Residuals Vs Regressors or independent 'x' variables or predictors 
# using Residual Regression Plots code graphics.plot_regress_exog(model,'x',fig)    # exog = x-variable & endog = y-variable
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Age',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'KM',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'HP',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'CC',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Doors',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Gears',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'QT',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Weight',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# # Model Deletion Diagnostics (checking Outliers or Influencers)

# %% [markdown]
# Two Techniques : 1. Cook's Distance & 2. Leverage value

# %%
# Cook's Distance: If Cook's distance > 1, then it's an outlier
# Get influencers using cook's distance
(c,_)=model.get_influence().cooks_distance
c
# Out:
# array([7.22221054e-03, 3.94547973e-03, 5.44224039e-03, ...,
#        8.04110550e-07, 6.99854767e-04, 1.08408002e-02])

# %%
# Plot the influencers using the stem plot
fig=plt.figure(figsize=(20,7))
plt.stem(np.arange(len(df4)),np.round(c,3))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
# Index and value of influencer where C>0.5
np.argmax(c) , np.max(c)
# Out:
# (80, 78.72950582249176)

# %%
# Leverage Value using High Influence Points : Points beyond Leverage_cutoff value are influencers
fig,ax=plt.subplots(figsize=(20,20))
fig=influence_plot(model,ax = ax)

# %%
# Leverage Cuttoff Value = 3*(k+1)/n ; k = no.of features/columns & n = no. of datapoints
k=df4.shape[1]
n=df4.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.022996515679442508

# %%
df4[df4.index.isin([80])]
# Out:
#     Price  Age     KM   HP     CC  Doors  Gears   QT  Weight  B_Boxcox
# 80  18950   25  20019  110  16000      5      5  100    1180  1.265274

# %% [markdown]
# # Improving the Model

# %%
# Creating a copy of data so that original dataset is not affected
df_new=df4.copy()
df_new
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight  B_Boxcox
# 0     13500   23  46986   90  2000      3      5  210    1165  1.265111
# 1     13750   23  72937   90  2000      3      5  210    1165  1.265121
# 2     13950   24  41711   90  2000      3      5  210    1165  1.265129
# 3     14950   26  48000   90  2000      3      5  210    1165  1.265165
# 4     13750   30  38500   90  2000      3      5  210    1170  1.265121
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...       ...
# 1430   7500   69  20544   86  1300      3      5   69    1025  1.264703
# 1431  10845   72  19000   86  1300      3      5   69    1015  1.264981
# 1432   8500   71  17016   86  1300      3      5   69    1015  1.264807
# 1433   7250   70  16916   86  1300      3      5   69    1015  1.264673
# 1434   6950   76      1  110  1600      5      5   19    1114  1.264635
#
# [1435 rows x 10 columns]

# %%
# Discard the data points which are influencers and reassign the row number (reset_index(drop=True))
df5=df_new.drop(df_new.index[[80]],axis=0).reset_index(drop=True)
df5
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight  B_Boxcox
# 0     13500   23  46986   90  2000      3      5  210    1165  1.265111
# 1     13750   23  72937   90  2000      3      5  210    1165  1.265121
# 2     13950   24  41711   90  2000      3      5  210    1165  1.265129
# 3     14950   26  48000   90  2000      3      5  210    1165  1.265165
# 4     13750   30  38500   90  2000      3      5  210    1170  1.265121
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...       ...
# 1429   7500   69  20544   86  1300      3      5   69    1025  1.264703
# 1430  10845   72  19000   86  1300      3      5   69    1015  1.264981
# 1431   8500   71  17016   86  1300      3      5   69    1015  1.264807
# 1432   7250   70  16916   86  1300      3      5   69    1015  1.264673
# 1433   6950   76      1  110  1600      5      5   19    1114  1.264635
#
# [1434 rows x 10 columns]

# %% [markdown]
# # Model Deletion Diagnostics and Final Model

# %%
 while np.max(c)>0.5 :
    model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=df5).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    df5=df5.drop(df5.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    df5
else:
    final_model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=df5).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.8882395145171202

# %%
if np.max(c)>0.5:
    model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=df5).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    df5=df5.drop(toyo5.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    df5 
elif np.max(c)<0.5:
    final_model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=df5).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.8882395145171202

# %%
final_model.rsquared
# Out:
# 0.8882395145171202

# %%
df5
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight  B_Boxcox
# 0     13500   23  46986   90  2000      3      5  210    1165  1.265111
# 1     13750   23  72937   90  2000      3      5  210    1165  1.265121
# 2     13950   24  41711   90  2000      3      5  210    1165  1.265129
# 3     14950   26  48000   90  2000      3      5  210    1165  1.265165
# 4     13750   30  38500   90  2000      3      5  210    1170  1.265121
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...       ...
# 1426   7500   69  20544   86  1300      3      5   69    1025  1.264703
# 1427  10845   72  19000   86  1300      3      5   69    1015  1.264981
# 1428   8500   71  17016   86  1300      3      5   69    1015  1.264807
# 1429   7250   70  16916   86  1300      3      5   69    1015  1.264673
# 1430   6950   76      1  110  1600      5      5   19    1114  1.264635
#
# [1431 rows x 10 columns]

# %% [markdown]
# # Model Predictions

# %%
# say New data for prediction is
new_data=pd.DataFrame({'Age':12,"KM":40000,"HP":80,"CC":1300,"Doors":4,"Gears":5,"QT":69,"Weight":1012},index=[0])
new_data
# Out:
#    Age     KM  HP    CC  Doors  Gears  QT  Weight
# 0   12  40000  80  1300      4      5  69    1012

# %%
# Manual Prediction of Price
final_model.predict(new_data)
# Out:
# 0    14341.570181
# dtype: float64

# %%
# Automatic Prediction of Price with 90.02% accurcy
pred_y=final_model.predict(df5)
pred_y
# Out:
# 0       16345.352610
# 1       15886.635544
# 2       16328.224968
# 3       15996.318854
# 4       15883.424182
#             ...
# 1426     9161.230587
# 1427     8536.091326
# 1428     8681.531063
# 1429     8793.668694
# 1430    10860.695492
# Length: 1431, dtype: float64
